# %% [markdown]
# <a href="https://colab.research.google.com/github/rafarahmatul25/KKA-X-SEMESTER1/blob/main/1_fungsipenggunaanprint_Rafa_X11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Rafa Rahmatul akbar
#
# Kelas:X-11
#
# No absen:28

# %% [markdown]
# #menampilkan teks bebas

# %%
print("Hello word")
# Out:
# Hello word

# %%
print ("Rafa Rahmatul Akbar")
# Out:
# Rafa Rahmatul Akbar

# %%
usia = 16
print(usia)
# Out:
# 16

# %% [markdown]
# #Menampilkan nilai variabel

# %%
harga_telur = 26000

print("Harga telur per 1 kg adalah", harga_telur)
# Out:
# Harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000

print("Harga telur per 1 kg adalah" + str(harga_telur))
# Out:
# Harga telur per 1 kg adalah26000

# %%
nama_pembeli = "Rafa"

print("Nama pembeli telur adalah " + nama_pembeli)
# Out:
# Nama pembeli telur adalah Rafa

# %%
print(f"Nama pembeli telur adalah {nama_pembeli}")
# Out:
# Nama pembeli telur adalah Rafa

# %%
nama_saudara=("Dira")
print(nama_saudara)
# Out:
# Dira

# %%
jumlah_saudara= 1
print(jumlah_saudara)
# Out:
# 1

# %%
nama_idola= "Hanan attaqi"
print(nama_idola)
# Out:
# Hanan attaqi

# %% [markdown]
# ##menampilkan Teks bebas dan nilai variabel

# %% [markdown]
# ##menampilkan teks bebas dan nilai variabel menggunakan tanda koma

# %%
print("saya memiliki saudara sebanyak",jumlah_saudara,"nama saudara saya adalah",nama_saudara)
# Out:
# saya memiliki saudara sebanyak 1 nama saudara saya adalah Dira

# %% [markdown]
# ##menampilkan teks bebas dan nilai variabel menggunakan tanda plus

# %%
print("saya memiliki saudara sebanyak"+ str(jumlah_saudara) + "." + "nama saudara saya adalah" + nama_saudara + ".")
# Out:
# saya memiliki saudara sebanyak1.nama saudara saya adalahDira.

# %% [markdown]
# #Menampilkan Teks bebas dan nilai nilai variabel menggunakan f string

# %%
print(f"Saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.")
# Out:
# Saya memiliki saudara sebanyak 1. Nama saudara saya adalah Dira.

# %% [markdown]
# ##Escape Character

# %% [markdown]
# Latihan Soal
#
# 1. Tampilkan teks bebas: Hari ini saya bahagia belajar bahasa python
# 2. Tampilkan nilai variabel: mata_pelajaran_favorit = Kode dan Kecerdasan Buatan
# 3. Tampilkan nilai variabel: nilai_kka = 100
# 4. Tampilkan teks bebas dan nilai variabel dengan tiga metode (f string, "+", ","): "Nilai KKA saya adalah {nilai_kka} loh!"

# %%
print("Nama:Rafa Rahmatul A")
print("Kelas:X-11")
print("No Absen:28")
# Out:
# Nama:Rafa Rahmatul A
# Kelas:X-11
# No Absen:28

# %%
print("Nama: Rafa Rahmatul A\nKelas:X-11\nNo.Absen:28")
# Out:
# Nama: Rafa Rahmatul A
# Kelas:X-11
# No.Absen:28

# %%
print("""Nama\t\t: Rafa Rahmatul A
Kelas\t\t:X-11
No.Absen\t:28""")
# Out:
# Nama		: Rafa Rahmatul A
# Kelas		:X-11
# No.Absen	:28

# %%
print("Rafa Rahmatul akbar")
# Out:
# Rafa Rahmatul akbar

# %%
print('Rafa Rahmatul akbar')
# Out:
# Rafa Rahmatul akbar

# %%
print('Habib ja\'far')
# Out:
# Habib ja'far

# %%
print("Habib ja'far")
# Out:
# Habib ja'far

# %%
print('Bu Shinta berkata,"Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata,"Harap fokus menyimak!".

# %%
print("Bu Shinta berkata \"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata "Harap fokus menyimak!".

# %%
print("Lokasi penyimpan tugas KKA di D:\\MAN Demak\\ Tugas")
# Out:
# Lokasi penyimpan tugas KKA di D:\MAN Demak\ Tugas

# %% [markdown]
# ##Parameter

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_1,nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1,end="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka

# %%
print(nama_siswa_3,end="-")
print(nama_siswa_2)
# Out:
# Haidar-Adzka

# %%
print(nama_siswa_1,end="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka

# %%
buah = "apel"
jumlah = 5
harga = 8000

total= harga * jumlah
print=(total)
